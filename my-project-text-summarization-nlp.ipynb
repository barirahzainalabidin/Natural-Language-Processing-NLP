# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/technology_data.csv
# /kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/sports_data.csv
# /kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/education_data.csv
# /kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/entertainment_data.csv
# /kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/business_data.csv

# %% [markdown]
# # TEXT SUMMARIZATION - BUSINESS

# %%
import csv

filename = load_doc_from_csv('/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/business_data.csv', 1)

def load_doc_from_csv(filename, text_column):
    """

    Args:
    - filename (str): The path to the CSV file.
    - text_column (int): The index of the column containing the text in the CSV file.

    Returns:
    - List[str]: A list of texts loaded from the CSV file.
    """
    texts = []
    with open(filename, 'r', encoding='utf-8') as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            if len(row) > text_column:
                texts.append(row[text_column])
    return texts

# %%
import os

filename = load_doc_from_csv('/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/business_data.csv', 1)

def load_stories(directory):
    """
    
    Args:
    - directory (str): The directory containing the text files.
    
    Returns:
    - List[str]: A list of documents loaded from the files.
    """
    documents = []
    for name in os.listdir(directory):
        filename = os.path.join(directory, name)
        if os.path.isfile(filename):
            # load document
            with open(filename, 'r', encoding='utf-8') as file:
                document = file.read()
                documents.append(document)
    return documents

# %%
import os

def load_stories(directory):
    """
    Args:
    - directory (str): The directory containing the text files.

    Returns:
    - List[str]: A list of documents loaded from the files.
    """
    documents = []
    for name in os.listdir(directory):
        filename = os.path.join(directory, name)
        # Check if the path is a file
        if os.path.isfile(filename):
            # Load document
            with open(filename, 'r', encoding='utf-8') as file:
                doc = file.read()
                documents.append(doc)
    return documents

# %% [markdown]
# > Split Story

# %%
def split_story(doc):
    """
    Split a document into news story and highlights.

    Args:
    - doc (str): The document containing the story and highlights.

    Returns:
    - Tuple[str, List[str]]: A tuple containing the story and a list of highlights.
    """
    # Find the first occurrence of '@headlines'
    index = doc.find('@headlines')
    
    # Split into story and headlines
    story, headlines = doc[:index], doc[index:].split('@headlines')
    
    # Strip extra white space around each headlines
    headlines = [h.strip() for h in headlines if len(h.strip()) > 0]
    
    return story.strip(), headlines

# %%
import pandas as pd

def load_stories(filename):
    """
    Load articles and their headlines from a CSV file.

    Args:
    - filename (str): The path to the CSV file containing articles.

    Returns:
    - list: A list of dictionaries containing articles and their headlines.
    """
    # Load CSV file
    df = pd.read_csv(filename)
    stories = []
    for idx, row in df.iterrows():
        article = row['content']
        headlines = row['headlines']
        stories.append({'article': article, 'headlines': headlines})
    return stories

# Load stories
file_path = '/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/business_data.csv'
stories = load_stories(file_path)
print('Loaded Content:', len(stories))
# Out:
# Loaded Content: 2000

# %%
import os
import pandas as pd

def load_stories(file_path):
    """
    Load stories and their headlines from a CSV file.

    Args:
    - file_path (str): The path to the CSV file containing the stories.

    Returns:
    - List[dict]: A list of dictionaries containing story and headlines.
    """
    # Check if the file exists
    if not os.path.isfile(file_path):
        print("File not found:", file_path)
        return []

    # Load stories from the CSV file
    df = pd.read_csv(file_path)
    stories = []
    for _, row in df.iterrows():
        story = row['content']  # Assuming 'content' is the column containing the story
        headlines = row['headlines']  # Assuming 'headlines' is the column containing the headlines
        stories.append({'story': story, 'headlines': headlines})
    return stories

# Load stories
file_path = '/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/business_data.csv'
stories = load_stories(file_path)
print('Loaded Stories with Headlines:', len(stories))
# Out:
# Loaded Stories with Headlines: 2000

# %% [markdown]
# In business news article, the number "2000" represents the count of such content and headlines items that have been successfully loaded and processed

# %% [markdown]
# # TEXT SUMMARIZATION IN TECHNOLOGY

# %%
import csv

filename = load_doc_from_csv('/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/technology_data.csv', 1)

def load_doc_from_csv(filename, text_column):
    """

    Args:
    - filename (str): The path to the CSV file.
    - text_column (int): The index of the column containing the text in the CSV file.

    Returns:
    - List[str]: A list of texts loaded from the CSV file.
    """
    texts = []
    with open(filename, 'r', encoding='utf-8') as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            if len(row) > text_column:
                texts.append(row[text_column])
    return texts

# %%
import os

filename = load_doc_from_csv('/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/technology_data.csv', 1)

def load_stories(directory):
    """
    
    Args:
    - directory (str): The directory containing the text files.
    
    Returns:
    - List[str]: A list of documents loaded from the files.
    """
    documents = []
    for name in os.listdir(directory):
        filename = os.path.join(directory, name)
        if os.path.isfile(filename):
            # load document
            with open(filename, 'r', encoding='utf-8') as file:
                document = file.read()
                documents.append(document)
    return documents

# %%
import os

def load_stories(directory):
    """
    Args:
    - directory (str): The directory containing the text files.

    Returns:
    - List[str]: A list of documents loaded from the files.
    """
    documents = []
    for name in os.listdir(directory):
        filename = os.path.join(directory, name)
        # Check if the path is a file
        if os.path.isfile(filename):
            # Load document
            with open(filename, 'r', encoding='utf-8') as file:
                doc = file.read()
                documents.append(doc)
    return documents

# %% [markdown]
# > Split Story

# %%
def split_story(doc):
    """
    Split a document into news story and highlights.

    Args:
    - doc (str): The document containing the story and highlights.

    Returns:
    - Tuple[str, List[str]]: A tuple containing the story and a list of highlights.
    """
    # Find the first occurrence of '@headlines'
    index = doc.find('@headlines')
    
    # Split into story and headlines
    story, headlines = doc[:index], doc[index:].split('@headlines')
    
    # Strip extra white space around each headlines
    headlines = [h.strip() for h in headlines if len(h.strip()) > 0]
    
    return story.strip(), headlines

# %%
import pandas as pd

def load_stories(filename):
    """
    Load articles and their headlines from a CSV file.

    Args:
    - filename (str): The path to the CSV file containing articles.

    Returns:
    - list: A list of dictionaries containing articles and their headlines.
    """
    # Load CSV file
    df = pd.read_csv(filename)
    stories = []
    for idx, row in df.iterrows():
        article = row['content']
        headlines = row['headlines']
        stories.append({'article': article, 'headlines': headlines})
    return stories

# Load stories
file_path = '/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/technology_data.csv'
stories = load_stories(file_path)
print('Loaded Content:', len(stories))
# Out:
# Loaded Content: 2000

# %%
import os
import pandas as pd

def load_stories(file_path):
    """
    Load stories and their headlines from a CSV file.

    Args:
    - file_path (str): The path to the CSV file containing the stories.

    Returns:
    - List[dict]: A list of dictionaries containing story and headlines.
    """
    # Check if the file exists
    if not os.path.isfile(file_path):
        print("File not found:", file_path)
        return []

    # Load stories from the CSV file
    df = pd.read_csv(file_path)
    stories = []
    for _, row in df.iterrows():
        story = row['content']  # Assuming 'content' is the column containing the story
        headlines = row['headlines']  # Assuming 'headlines' is the column containing the headlines
        stories.append({'story': story, 'headlines': headlines})
    return stories

# Load stories
file_path = '/kaggle/input/news-articles-classification-dataset-for-nlp-and-ml/technology_data.csv'
stories = load_stories(file_path)
print('Loaded Stories with Headlines:', len(stories))
# Out:
# Loaded Stories with Headlines: 2000

# %% [markdown]
# In technology news article, the number "2000" represents the count of such content and headlines items that have been successfully loaded and processed
